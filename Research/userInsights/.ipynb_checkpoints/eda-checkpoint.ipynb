# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_word_cloud(text: str):
    """
    Generates and displays a word cloud from the given text.
    """
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

generate_word_cloud(rawText)

# %%
from collections import Counter
import re

def top_10_frequent_words(text: str):
    """
    Returns the top 10 most frequent words and their word counts.
    """
    words = re.findall(r'\w+', text.lower())
    word_counts = Counter(words)
    return word_counts.most_common(10)

top_10_frequent_words(rawText)
# Out:
# [('stress', 34),
#  ('and', 33),
#  ('of', 20),
#  ('to', 20),
#  ('the', 19),
#  ('can', 18),
#  ('a', 17),
#  ('or', 15),
#  ('is', 13),
#  ('as', 11)]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

def top_10_topics(texts: list, n_topics: int = 10):
    """
    Perform topic modeling using LDA and return the top 10 topics with their words.
    """
    vectorizer = CountVectorizer(stop_words='english')
    X = vectorizer.fit_transform(texts)
    
    lda = LatentDirichletAllocation(n_components=n_topics)
    lda.fit(X)
    
    words = vectorizer.get_feature_names_out()
    topics = []
    
    for topic_idx, topic in enumerate(lda.components_):
        topic_words = [words[i] for i in topic.argsort()[:-11:-1]]
        topics.append(f"Topic {topic_idx + 1}: " + ", ".join(topic_words))
    
    return topics
top_10_topics(rawText)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 22
#      19         topics.append(f"Topic {topic_idx + 1}: " + ", ".join(topic_words))
#      21     return topics
# ---> 22 top_10_topics(rawText)
#
# Cell In[8], line 9, in top_10_topics(texts, n_topics)
#       5 """
#       6 Perform topic modeling using LDA and return the top 10 topics with their words.
#       7 """
#       8 vectorizer = CountVectorizer(stop_words='english')
# ----> 9 X = vectorizer.fit_transform(texts)
#      11 lda = LatentDirichletAllocation(n_components=n_topics)
#      12 lda.fit(X)
#
# File ~\Documents\GitHub\SuperMind\Research\userInsights\venv\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\Documents\GitHub\SuperMind\Research\userInsights\venv\Lib\site-packages\sklearn\feature_extraction\text.py:1354, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1350 # We intentionally don't call the transform method to make
#    1351 # fit_transform overridable without unwanted side effects in
#    1352 # TfidfVectorizer.
#    1353 if isinstance(raw_documents, str):
# -> 1354     raise ValueError(
#    1355         "Iterable over raw text documents expected, string object received."
#    1356     )
#    1358 self._validate_ngram_range()
#    1359 self._warn_for_unused_params()
#
# ValueError: Iterable over raw text documents expected, string object received.

# %%
def word_frequency(text: str):
    """
    Returns a dictionary of all words and their frequency, sorted by frequency (high to low).
    """
    words = re.findall(r'\w+', text.lower())
    word_counts = Counter(words)
    return dict(word_counts.most_common())

word_frequency(rawText)
# Out:
# {'stress': 34,
#  'and': 33,
#  'of': 20,
#  'to': 20,
#  'the': 19,
#  'can': 18,
#  'a': 17,
#  'or': 15,
#  'is': 13,
#  'as': 11,
#  'in': 10,
#  'individuals': 10,
#  'physical': 9,
#  'mental': 7,
#  'health': 7,
#  'may': 7,
#  'chronic': 6,
#  'effects': 6,
#  'such': 6,
#  'body': 5,
#  'when': 5,
#  'have': 5,
#  'are': 5,
#  'their': 5,
#  'which': 4,
#  'this': 4,
#  'help': 4,
#  'it': 4,
#  'on': 4,
#  'high': 4,
#  'system': 4,
#  's': 4,
#  'with': 4,
#  'its': 4,
#  'managing': 4,
#  'for': 4,
#  'challenges': 3,
#  'emotional': 3,
#  'be': 3,
#  'negative': 3,
#  'both': 3,
#  'lead': 3,
#  'issues': 3,
#  'heart': 3,
#  'person': 3,
#  'these': 3,
#  'impact': 3,
#  'also': 3,
#  'digestive': 3,
#  'maintaining': 3,
#  'that': 3,
#  'natural': 2,
#  'response': 2,
#  'variety': 2,
#  'beneficial': 2,
#  'stay': 2,
#  'often': 2,
#  'productivity': 2,
#  'however': 2,
#  'becomes': 2,
#  'excessive': 2,
#  'serious': 2,
#  'disease': 2,
#  'blood': 2,
#  'pressure': 2,
#  'anxiety': 2,
#  'depression': 2,
#  'by': 2,
#  'release': 2,
#  'from': 2,
#  'muscle': 2,
#  'tension': 2,
#  'changes': 2,
#  'during': 2,
#  'one': 2,
#  'most': 2,
#  'feelings': 2,
#  'contribute': 2,
#  'mood': 2,
#  'making': 2,
#  'over': 2,
#  'time': 2,
#  'reduce': 2,
#  'relationships': 2,
#  'more': 2,
#  'sleep': 2,
#  'experience': 2,
#  'problems': 2,
#  'coping': 2,
#  'mechanisms': 2,
#  'social': 2,
#  'life': 2,
#  'affects': 2,
#  'effectively': 2,
#  'well': 2,
#  'being': 2,
#  'techniques': 2,
#  'consequences': 2,
#  'activity': 2,
#  'ways': 2,
#  'practicing': 2,
#  'healthy': 2,
#  'lifestyle': 2,
#  'balanced': 2,
#  'essential': 2,
#  'external': 1,
#  'pressures': 1,
#  'threats': 1,
#  'trigger': 1,
#  'reactions': 1,
#  'small': 1,
#  'doses': 1,
#  'helping': 1,
#  'alert': 1,
#  'focused': 1,
#  'motivated': 1,
#  'overcome': 1,
#  'type': 1,
#  'referred': 1,
#  'eustress': 1,
#  'enhance': 1,
#  'performance': 1,
#  'increase': 1,
#  'meet': 1,
#  'deadlines': 1,
#  'achieve': 1,
#  'goals': 1,
#  'called': 1,
#  'distress': 1,
#  'range': 1,
#  'including': 1,
#  'diabetes': 1,
#  'weakened': 1,
#  'immune': 1,
#  'governed': 1,
#  'autonomic': 1,
#  'nervous': 1,
#  'hormones': 1,
#  'adrenaline': 1,
#  'cortisol': 1,
#  'perceives': 1,
#  'threat': 1,
#  'enters': 1,
#  'fight': 1,
#  'flight': 1,
#  'mode': 1,
#  'preparing': 1,
#  'either': 1,
#  'confront': 1,
#  'flee': 1,
#  'danger': 1,
#  'results': 1,
#  'increased': 1,
#  'rate': 1,
#  'rapid': 1,
#  'breathing': 1,
#  'heightened': 1,
#  'awareness': 1,
#  'adaptive': 1,
#  'situations': 1,
#  'where': 1,
#  'immediate': 1,
#  'action': 1,
#  'required': 1,
#  'faced': 1,
#  'dangerous': 1,
#  'predator': 1,
#  'stressful': 1,
#  'work': 1,
#  'deadline': 1,
#  'prolonged': 1,
#  'continuously': 1,
#  'exposed': 1,
#  'physiological': 1,
#  'detrimental': 1,
#  'noticeable': 1,
#  'irritability': 1,
#  'exhaustion': 1,
#  'disorders': 1,
#  'post': 1,
#  'traumatic': 1,
#  'disorder': 1,
#  'ptsd': 1,
#  'levels': 1,
#  'difficulty': 1,
#  'concentrating': 1,
#  'decisions': 1,
#  'remembering': 1,
#  'important': 1,
#  'tasks': 1,
#  'constant': 1,
#  'state': 1,
#  'alertness': 1,
#  'impair': 1,
#  'cognitive': 1,
#  'function': 1,
#  'harder': 1,
#  'think': 1,
#  'clearly': 1,
#  'logically': 1,
#  'negatively': 1,
#  'affect': 1,
#  'personal': 1,
#  'become': 1,
#  'withdrawn': 1,
#  'prone': 1,
#  'conflict': 1,
#  'physically': 1,
#  'cause': 1,
#  'symptoms': 1,
#  'common': 1,
#  'manifestations': 1,
#  'include': 1,
#  'headaches': 1,
#  'disturbances': 1,
#  'people': 1,
#  'under': 1,
#  'likely': 1,
#  'cardiovascular': 1,
#  'has': 1,
#  'been': 1,
#  'linked': 1,
#  'like': 1,
#  'irritable': 1,
#  'bowel': 1,
#  'syndrome': 1,
#  'ibs': 1,
#  'acid': 1,
#  'reflux': 1,
#  'disrupted': 1,
#  'periods': 1,
#  'moreover': 1,
#  'resort': 1,
#  'unhealthy': 1,
#  'overeating': 1,
#  'smoking': 1,
#  'alcohol': 1,
#  'consumption': 1,
#  'further': 1,
#  'exacerbate': 1,
#  'addition': 1,
#  'toll': 1,
#  'an': 1,
#  'withdrawal': 1,
#  'interactions': 1,
#  'feel': 1,
#  'overwhelmed': 1,
#  'unable': 1,
#  'engage': 1,
#  'conversations': 1,
#  'activities': 1,
#  'isolation': 1,
#  'deepen': 1,
#  'loneliness': 1,
#  'worsening': 1,
#  'friends': 1,
#  'family': 1,
#  'colleagues': 1,
#  'suffer': 1,
#  'ability': 1,
#  'communicate': 1,
#  'empathize': 1,
#  'crucial': 1,
#  'various': 1,
#  'strategies': 1,
#  'alleviate': 1,
#  'prevent': 1,
#  'regular': 1,
#  'walking': 1,
#  'yoga': 1,
#  'swimming': 1,
#  'effective': 1,
#  'exercise': 1,
#  'promotes': 1,
#  'endorphins': 1,
#  'boosters': 1,
#  'counteract': 1,
#  'mindfulness': 1,
#  'meditation': 1,
#  'practices': 1,
#  'present': 1,
#  'moment': 1,
#  'calm': 1,
#  'minds': 1,
#  'regulate': 1,
#  'responses': 1,
#  'additionally': 1,
#  'includes': 1,
#  'getting': 1,
#  'adequate': 1,
#  'eating': 1,
#  'diet': 1,
#  'staying': 1,
#  'hydrated': 1,
#  'conclusion': 1,
#  'complex': 1,
#  'multifaceted': 1,
#  'different': 1,
#  'while': 1,
#  'short': 1,
#  'term': 1,
#  'motivating': 1,
#  'energizing': 1,
#  'recognizing': 1,
#  'signs': 1,
#  'adopting': 1,
#  'reducing': 1,
#  'engaging': 1,
#  'relaxation': 1,
#  'mitigate': 1,
#  'harmful': 1,
#  'improve': 1,
#  'overall': 1,
#  'ultimately': 1,
#  'management': 1,
#  'about': 1,
#  'finding': 1,
#  'balance': 1,
#  'allows': 1,
#  'cope': 1,
#  'without': 1,
#  'compromising': 1,
#  'happiness': 1}

# %%
import spacy

def extract_brands(text: str):
    """
    python -m spacy download en_core_web_sm
    
    Extracts a list of brand names (organizations) from the text using NER.
    """
    nlp = spacy.load("en_core_web_md")
    doc = nlp(text)
    brands = [ent.text for ent in doc.ents if ent.label_ == 'ORG']
    return list(set(brands))  # Remove duplicates

extract_brands(rawText)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 14
#      11     brands = [ent.text for ent in doc.ents if ent.label_ == 'ORG']
#      12     return list(set(brands))  # Remove duplicates
# ---> 14 extract_brands(rawText)
#
# Cell In[18], line 9, in extract_brands(text)
#       3 def extract_brands(text: str):
#       4     """
#       5     python -m spacy download en_core_web_sm
#       6
#       7     Extracts a list of brand names (organizations) from the text using NER.
#       8     """
# ----> 9     nlp = spacy.load("en_core_web_md")
#      10     doc = nlp(text)
#      11     brands = [ent.text for ent in doc.ents if ent.label_ == 'ORG']
#
# File ~\Documents\GitHub\SuperMind\Research\userInsights\venv\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File ~\Documents\GitHub\SuperMind\Research\userInsights\venv\Lib\site-packages\spacy\util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_md'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
def extract_locations(text: str):
    """
    Extracts a list of location names (places, countries, cities) from the text using NER.
    """
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    locations = [ent.text for ent in doc.ents if ent.label_ == 'GPE']
    return list(set(locations))  # Remove duplicates

extract_locations(rawText)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 10
#       7     locations = [ent.text for ent in doc.ents if ent.label_ == 'GPE']
#       8     return list(set(locations))  # Remove duplicates
# ---> 10 extract_locations(rawText)
#
# Cell In[15], line 5, in extract_locations(text)
#       1 def extract_locations(text: str):
#       2     """
#       3     Extracts a list of location names (places, countries, cities) from the text using NER.
#       4     """
# ----> 5     nlp = spacy.load("en_core_web_sm")
#       6     doc = nlp(text)
#       7     locations = [ent.text for ent in doc.ents if ent.label_ == 'GPE']
#
# File ~\Documents\GitHub\SuperMind\Research\userInsights\venv\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File ~\Documents\GitHub\SuperMind\Research\userInsights\venv\Lib\site-packages\spacy\util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
def extract_persons(text: str):
    """
    Extracts a list of well-known persons' names from the text using NER.
    """
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    persons = [ent.text for ent in doc.ents if ent.label_ == 'PERSON']
    return list(set(persons))  # Remove duplicates

extract_persons(rawText)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[16], line 10
#       7     persons = [ent.text for ent in doc.ents if ent.label_ == 'PERSON']
#       8     return list(set(persons))  # Remove duplicates
# ---> 10 extract_persons(rawText)
#
# Cell In[16], line 5, in extract_persons(text)
#       1 def extract_persons(text: str):
#       2     """
#       3     Extracts a list of well-known persons' names from the text using NER.
#       4     """
# ----> 5     nlp = spacy.load("en_core_web_sm")
#       6     doc = nlp(text)
#       7     persons = [ent.text for ent in doc.ents if ent.label_ == 'PERSON']
#
# File ~\Documents\GitHub\SuperMind\Research\userInsights\venv\Lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File ~\Documents\GitHub\SuperMind\Research\userInsights\venv\Lib\site-packages\spacy\util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
